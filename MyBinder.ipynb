# %% [markdown]
# # CIFAR 10 Classification: Local GPU Version
#
# The goal of this notebook is to implement a simple conv net to classify CIFAR10 images and compare the training time against Colab GPU and TPU Notebooks.

# %% [markdown]
# # Imports

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

from time import time
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_31/3338676528.py in <module>
#       3
#       4 from time import time
# ----> 5 import numpy as np
#       6 from sklearn.model_selection import train_test_split
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# check tensorflow version, we want the one that support eager mode
tf.__version__
# Out:
# '1.11.0'

# %%
# Check if eager execution mode is on
tf.executing_eagerly()
# Out:
# False

# %% [markdown]
# # Dataset
#
# Load CIFAR10 dataset, split training set into train and validation set

# %%
from tensorflow.keras.datasets import cifar10, mnist

(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
print('x_train_full shape: {}, y_train_full.shape: {}'
      .format(x_train_full.shape, y_train_full.shape))
print('x_test shape: {}, y_test.shape: {}'.format(x_test.shape, y_test.shape))
# Out:
# x_train_full shape: (50000, 32, 32, 3), y_train_full.shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3), y_test.shape: (10000, 1)

# %%
y_train_full = y_train_full.reshape(y_train_full.shape[0],)
y_test = y_test.reshape(y_test.shape[0],)
print('y_train_full shape: {}, y_test shape: {}'
      .format(y_train_full.shape, y_test.shape))
# Out:
# y_train_full shape: (50000,), y_test shape: (10000,)

# %%
# create validation set
split = 0.2
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42)
print('x_train: {}, y_train: {}, x_val: {}, y_val: {}'
      .format(x_train.shape, y_train.shape, x_val.shape, y_val.shape))
# Out:
# x_train: (40000, 32, 32, 3), y_train: (40000,), x_val: (10000, 32, 32, 3), y_val: (10000,)

# %% [markdown]
# Lets plot 25 random images to get some idea about the dataset

# %%
# pick 25 random images and plot
idxs = np.random.randint(x_train.shape[0], size=25)
images = x_train[idxs]
labels = y_train[idxs]
classnames = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig, axes = plt.subplots(5,5, figsize=(8,9))
for i, ax in enumerate(axes.flat):
  ax.imshow(images[i])
  ax.axis('off')
  idx = labels[i]
  ax.set_title(classnames[idx])
  
plt.show()

# %%
def train_gen(batch_size):
  while True:
    offset = np.random.randint(0, x_train.shape[0] - batch_size)
    yield x_train[offset:offset+batch_size], y_train[offset:offset + batch_size]

# %% [markdown]
# # Build a model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3,3)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(10, activation='relu'))
model.add(tf.keras.layers.Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 111,946
# Trainable params: 111,498
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# # Train
#
# Train the model

# %%
model.compile(
    optimizer=tf.train.AdamOptimizer(learning_rate=1e-3, ),
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['sparse_categorical_accuracy']
)

# %%
batch_size=1024
start = time()
history = model.fit_generator(
    train_gen(batch_size), epochs=25, 
    steps_per_epoch=np.ceil(x_train.shape[0]/batch_size).astype(int) ,
    validation_data = (x_val, y_val),
)
end = time()
# Out:
# Epoch 1/25
# 40/40 [==============================] - 3s 82ms/step - loss: 2.1633 - sparse_categorical_accuracy: 0.2391 - val_loss: 2.7440 - val_sparse_categorical_accuracy: 0.1540
# Epoch 2/25
# 40/40 [==============================] - 1s 31ms/step - loss: 1.6704 - sparse_categorical_accuracy: 0.4323 - val_loss: 2.0303 - val_sparse_categorical_accuracy: 0.2851
# Epoch 3/25
# 40/40 [==============================] - 1s 30ms/step - loss: 1.3974 - sparse_categorical_accuracy: 0.5239 - val_loss: 1.6822 - val_sparse_categorical_accuracy: 0.4266
# Epoch 4/25
# 40/40 [==============================] - 1s 30ms/step - loss: 1.2097 - sparse_categorical_accuracy: 0.5837 - val_loss: 1.5359 - val_sparse_categorical_accuracy: 0.4632
# Epoch 5/25
# 40/40 [==============================] - 1s 30ms/step - loss: 1.1169 - sparse_categorical_accuracy: 0.6181 - val_loss: 1.3551 - val_sparse_categorical_accuracy: 0.5376
# Epoch 6/25
# 40/40 [==============================] - 1s 31ms/step - loss: 0.9910 - sparse_categorical_accuracy: 0.6583 - val_loss: 1.1708 - val_sparse_categorical_accuracy: 0.5826
# Epoch 7/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.9425 - sparse_categorical_accuracy: 0.6732 - val_loss: 1.0856 - val_sparse_categorical_accuracy: 0.6208
# Epoch 8/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.8740 - sparse_categorical_accuracy: 0.7043 - val_loss: 1.0367 - val_sparse_categorical_accuracy: 0.6374
# Epoch 9/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.8206 - sparse_categorical_accuracy: 0.7171 - val_loss: 1.0354 - val_sparse_categorical_accuracy: 0.6416
# Epoch 10/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.7822 - sparse_categorical_accuracy: 0.7332 - val_loss: 1.0401 - val_sparse_categorical_accuracy: 0.6401
# Epoch 11/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.7352 - sparse_categorical_accuracy: 0.7483 - val_loss: 0.9465 - val_sparse_categorical_accuracy: 0.6719
# Epoch 12/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.6836 - sparse_categorical_accuracy: 0.7658 - val_loss: 0.9379 - val_sparse_categorical_accuracy: 0.6724
# Epoch 13/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.6595 - sparse_categorical_accuracy: 0.7724 - val_loss: 0.9744 - val_sparse_categorical_accuracy: 0.6777
# Epoch 14/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.5983 - sparse_categorical_accuracy: 0.7965 - val_loss: 0.9121 - val_sparse_categorical_accuracy: 0.6894
# Epoch 15/25
# 40/40 [==============================] - 1s 31ms/step - loss: 0.5784 - sparse_categorical_accuracy: 0.7994 - val_loss: 0.9920 - val_sparse_categorical_accuracy: 0.6766
# Epoch 16/25
# 40/40 [==============================] - 1s 31ms/step - loss: 0.5360 - sparse_categorical_accuracy: 0.8162 - val_loss: 0.9452 - val_sparse_categorical_accuracy: 0.6967
# Epoch 17/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.5032 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.9307 - val_sparse_categorical_accuracy: 0.7046
# Epoch 18/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.5120 - sparse_categorical_accuracy: 0.8244 - val_loss: 1.0015 - val_sparse_categorical_accuracy: 0.6857
# Epoch 19/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.4390 - sparse_categorical_accuracy: 0.8478 - val_loss: 0.9809 - val_sparse_categorical_accuracy: 0.6949
# Epoch 20/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.4243 - sparse_categorical_accuracy: 0.8531 - val_loss: 1.0298 - val_sparse_categorical_accuracy: 0.6932
# Epoch 21/25
# 40/40 [==============================] - 1s 31ms/step - loss: 0.4126 - sparse_categorical_accuracy: 0.8577 - val_loss: 1.2946 - val_sparse_categorical_accuracy: 0.6532
# Epoch 22/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.3835 - sparse_categorical_accuracy: 0.8685 - val_loss: 1.0289 - val_sparse_categorical_accuracy: 0.7010
# Epoch 23/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.3766 - sparse_categorical_accuracy: 0.8685 - val_loss: 1.0658 - val_sparse_categorical_accuracy: 0.6943
# Epoch 24/25
# 40/40 [==============================] - 1s 30ms/step - loss: 0.3430 - sparse_categorical_accuracy: 0.8821 - val_loss: 1.1627 - val_sparse_categorical_accuracy: 0.6767
# Epoch 25/25
# 40/40 [==============================] - 1s 31ms/step - loss: 0.3026 - sparse_categorical_accuracy: 0.8955 - val_loss: 1.0991 - val_sparse_categorical_accuracy: 0.6961

# %%
print('Total training time {} seconds'.format(end - start))
# Out:
# Total training time 32.48600769042969 seconds

# %%
def plot(losses, accuracies, subplot_title):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,4))
  
  ax1.plot(losses)
  ax1.set_xlabel('Epochs')
  ax1.set_ylabel('Loss')
  ax1.set_title(subplot_title[0])
  
  ax2.plot(accuracies)
  ax2.set_xlabel('Epochs')
  ax2.set_ylabel('Accuracy')
  ax2.set_title(subplot_title[1])
    
  plt.show()

# %% [markdown]
# ### Plot Loss and Accuracy

# %%
# Training
plot(history.history['loss'], 
     history.history['sparse_categorical_accuracy'], 
     subplot_title=['Training Loss', 'Training Accuracy']
    )

# %%
# Validation
plot(history.history['val_loss'], 
     history.history['val_sparse_categorical_accuracy'], 
     subplot_title=['Validation Loss', 'Validation Accuracy']
    )

# %% [markdown]
# # Test accuracy
#
# Next, we plot the model predictions on test set

# %%
idxs = np.random.randint(x_test.shape[0], size=25)
images = x_test[idxs]
true_labels = y_test[idxs]

preds = np.argmax(model.predict(images), axis=1)

# %%
fig, axes = plt.subplots(5,5, figsize=(8,9))
for i, ax in enumerate(axes.flat):
  ax.imshow(images[i])
  ax.axis('off')
  idx = preds[i]
  color = 'g' if idx == true_labels[i] else 'r'
  ax.set_title(classnames[idx], color=color)

plt.show()

# %% [markdown]
# Next, you can see the results from Colab GPU and TPU notebooks:
#
# * <a href="https://colab.research.google.com/drive/1UCMQJDpJ5hEiUEQ4qMAj0UBiYQ6n8Yg-">GPU Notebook</a>
# * <a href="https://colab.research.google.com/drive/1rP91Q5L1mPOVt7FcKkqFJSIMZrBtDawO">TPU Notebook</a>
